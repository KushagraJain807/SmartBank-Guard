# %% [markdown]
# # SmartBank Guard — Fraud Detection\nEnd-to-end notebook for EDA, preprocessing, model comparison and evaluation.

# %%
import pandas as pd\nfrom sklearn.datasets import fetch_openml\ndf = fetch_openml(name='creditcard', version=1, as_frame=True, parser='auto').frame\ndf.head()

# %%
df.info()\ndf['Class'].value_counts(normalize=True) * 100

# %%
import matplotlib.pyplot as plt\nimport seaborn as sns\nsns.countplot(data=df, x='Class')\nplt.title('Class Distribution')\nplt.show()

# %% [markdown]
# ## Next step\nRun `src/train.py` from the project root. It performs the reproducible train/test split, trains three models, compares metrics, saves the best model, and generates the confusion matrix and ROC curve.
